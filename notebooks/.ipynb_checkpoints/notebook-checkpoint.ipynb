# %%
import pandas as pd

df = pd.read_csv('~/development/greatwall/data/data_clean.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

annual_aggregates = df.groupby(['year'])['price_clean'].agg(['sum'])
annual_aggregates.reset_index(level=0, inplace=True)

sns.set_style('white')
plt.bar(annual_aggregates['year'],annual_aggregates['sum'])
sns.despine()
plt.xlabel('Year')
plt.ylabel('Volume \n (Billion Yuan)') # this isn't right, needs right units
plt.title('Annual Volume of NPL Disposal Auctions')
# Out:
# Text(0.5,1,'Annual Volume of NPL Disposal Auctions')

# %%
# Volume by Region

df_regions = df[df['year'] == 2018].groupby(['region'])['price_clean'].agg(['sum'])
df_regions = df_regions.reset_index()
df_regions['total'] = df_regions['sum'].sum()
df_regions['share_of_total'] = df_regions['sum']/df_regions['total']
df_regions
# Out:
#              region           sum         total  share_of_total
# 0   Autonomous West  4.353488e+10  2.635343e+11        0.165196
# 1         Northeast  1.886478e+10  2.635343e+11        0.071584
# 2   Populous Middle  2.213095e+10  2.635343e+11        0.083977
# 3  Prosperous Coast  1.744614e+11  2.635343e+11        0.662006
# 4         Rust Belt  4.542283e+09  2.635343e+11        0.017236

# %%
# Volume by Province

df_provinces = df[df['year'] == 2018].groupby(['CityName'])['price_clean'].agg(['sum'])

df_provinces.sort_values(by = 'sum', ascending = False).head()
# Out:
#                    sum
# CityName
# 北京        1.570759e+11
# 广西        1.954609e+10
# 云南        1.632147e+10
# 辽宁        1.488219e+10
# 四川        1.000652e+10

# %%
# Volume by Region

thing = df.groupby(['region','year'])['price_clean'].agg(['sum']).reset_index()

thing
# Out:
#               region  year           sum
# 0    Autonomous West  2008  6.805000e+08
# 1    Autonomous West  2009  8.150000e+08
# 2    Autonomous West  2010  1.219500e+09
# 3    Autonomous West  2011  6.170000e+08
# 4    Autonomous West  2012  3.375000e+08
# 5    Autonomous West  2013  3.070000e+08
# 6    Autonomous West  2014  2.051110e+07
# 7    Autonomous West  2015  2.293162e+08
# 8    Autonomous West  2016  3.588285e+09
# 9    Autonomous West  2017  1.547442e+10
# 10   Autonomous West  2018  4.353488e+10
# 11         Northeast  2006  1.500000e+06
# 12         Northeast  2007  1.926500e+09
# 13         Northeast  2008  1.029150e+10
# 14         Northeast  2009  2.066950e+10
# 15         Northeast  2010  1.576350e+10
# 16         Northeast  2011  2.346800e+10
# 17         Northeast  2012  1.723600e+10
# 18         Northeast  2013  5.161676e+09
# 19         Northeast  2014  9.132702e+09
# 20         Northeast  2015  2.024535e+10
# 21         Northeast  2016  1.055926e+10
# 22         Northeast  2017  4.228009e+10
# 23         Northeast  2018  1.886478e+10
# 24   Populous Middle  2007  5.000000e+05
# 25   Populous Middle  2008  1.709500e+09
# 26   Populous Middle  2009  1.245500e+09
# 27   Populous Middle  2010  2.143500e+09
# 28   Populous Middle  2011  1.236000e+09
# 29   Populous Middle  2012  7.585000e+08
# 30   Populous Middle  2013  1.035000e+08
# 31   Populous Middle  2014  6.884151e+07
# 32   Populous Middle  2015  1.023335e+09
# 33   Populous Middle  2016  6.294356e+09
# 34   Populous Middle  2017  1.511722e+10
# 35   Populous Middle  2018  2.213095e+10
# 36  Prosperous Coast  2007  2.365000e+08
# 37  Prosperous Coast  2008  1.095650e+10
# 38  Prosperous Coast  2009  1.608150e+10
# 39  Prosperous Coast  2010  4.768000e+09
# 40  Prosperous Coast  2011  9.236000e+09
# 41  Prosperous Coast  2012  6.072500e+09
# 42  Prosperous Coast  2013  2.784000e+09
# 43  Prosperous Coast  2014  5.864046e+09
# 44  Prosperous Coast  2015  2.629945e+10
# 45  Prosperous Coast  2016  1.419240e+10
# 46  Prosperous Coast  2017  6.413416e+10
# 47  Prosperous Coast  2018  1.744614e+11
# 48         Rust Belt  2007  3.000000e+07
# 49         Rust Belt  2008  6.739000e+09
# 50         Rust Belt  2009  3.448000e+09
# 51         Rust Belt  2010  3.295500e+09
# 52         Rust Belt  2011  1.757500e+09
# 53         Rust Belt  2012  1.393500e+09
# 54         Rust Belt  2013  3.110000e+08
# 55         Rust Belt  2014  5.114788e+04
# 56         Rust Belt  2015  1.206102e+09
# 57         Rust Belt  2016  1.041015e+10
# 58         Rust Belt  2017  2.146693e+10
# 59         Rust Belt  2018  4.542283e+09
